# %%
import re
import matplotlib.pyplot as plt

# log_file = "./checkpoint/20251207-015135/train.log" # 4 mg, 3 pre, 3 post
log_file = "./checkpoint/20251207-111229/train.log" # 6 mg, 3 pre, 3 post


# Read the file and extract epoch and loss values
epochs = []
losses = []

with open(log_file, "r") as f:
    for line in f:
        match = re.search(r"\[Epoch (\d+)/\d+\] loss = ([0-9\.eE+-]+)", line)
        if match:
            epoch = int(match.group(1))
            loss = float(match.group(2))
            epochs.append(epoch)
            losses.append(loss)

# Plotting
plt.figure(figsize=(10, 6))
plt.plot(epochs, losses, marker="o")
plt.title("Training Loss over Epochs")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.yscale("log")
plt.grid(True)
plt.show()
